# %% [markdown]
# # Data Analysis Assignment 1
# ## Adam Fair

# %%
# Load in this cell any packages that you will use in this assignment
require(tidyverse)
require(gapminder)
# Out:
# Loading required package: tidyverse
# Registered S3 methods overwritten by 'ggplot2':
#   method         from
#   [.quosures     rlang
#   c.quosures     rlang
#   print.quosures rlang
# Registered S3 method overwritten by 'rvest':
#   method            from
#   read_xml.response xml2
# -- Attaching packages --------------------------------------- tidyverse 1.2.1 --
# v ggplot2 3.1.1       v purrr   0.3.2
# v tibble  2.1.1       v dplyr   0.8.0.1
# v tidyr   0.8.3       v stringr 1.4.0
# v readr   1.3.1       v forcats 0.4.0
# -- Conflicts ------------------------------------------ tidyverse_conflicts() --
# x dplyr::filter() masks stats::filter()
# x dplyr::lag()    masks stats::lag()
# Loading required package: gapminder
# Warning message:
# "package 'gapminder' was built under R version 3.6.3"

# %% [markdown]
# ## Section 1 Exercises

# %%
  gapminder07 <- dplyr::filter(gapminder, year == 2007)

# %%
ggplot(data = gapminder07)
# Out:
# plot without title

# %% [markdown]
# ### 1. (5 pts.) Run ggplot(data = gapminder07). What do you see and why?
# After running ggplot(data = gapminder07), I see an empty plot. This is because the ggplot() function creates a coordinate system that you can add layers to. The first argument of the function is the dataset to use in the graph. Therefore, running ggplot(data = gapminder07) with no furthur arguments creates an empty graph.

# %%
dim(gapminder07)
# Out:
# [1] 142   6

# %% [markdown]
# ### 2. (5 pts.) How many rows are in gapminder07? How many columns?
# There are 142 rows and 6 columns. This answer was found using the `dim()` function.

# %% [markdown]
# ## Section 2 Exercises

# %%
ggplot(data = gapminder07) + 
    geom_text(mapping = aes(x = gdpPercap, y = lifeExp, label = country)) +
    coord_trans(x="log") +
    xlab("Natural Log of GDP per Capita") +
    ylab("Life Expectancy") +
    geom_smooth(mapping = aes(x = gdpPercap, y = lifeExp), method = "lm", se = FALSE)
# Out:
# plot without title

# %% [markdown]
# ### 1. (15 pts.) Google the geom_text command and use this to plot the graph with country names instead of points, as below. Note that the GDP variable is very unevenly distributed across the horizontal axis. Use Google to find out how to convert the horizontal axis to a log-scale in ggplot2 (don’t forget to appropriately rename axis labels as well, and as always in economics, make sure to use the natural log function.) Then, Google the geom_smooth command and use this to add a linear fitted line to this graph. Make sure your code produces the plot in the file containing your answers. Note: this applies to all questions where you are asked to create a graph or other type of output.

# %%
ggplot(data = gapminder07) + 
    geom_text(mapping = aes(x = gdpPercap, y = lifeExp, label = country)) +
    coord_trans(x="log") +
    xlab("Natural Log of GDP per Capita") +
    ylab("Life Expectancy") +
    geom_smooth(mapping = aes(x = gdpPercap, y = lifeExp), method = "lm", se = FALSE) +
    scale_x_continuous(trans = 'log', breaks = 1000* 2**(0:10))
# Out:
# plot without title

# %% [markdown]
# ### 2. (5 pts.) Some countries are considerably below the line. Why do you think they are so much below? Try checking the Wikipedia of two of these countries and give an hypothesis.

# %% [markdown]
# For this response I examined the Wikipedia articles for the countries of Afghanistan and Rawanda looked for common themes between the two countries. I believe that the countries that lie signifigantly below the fitted linear regression line of life expectancy and GDP per capita are result of being landlocked with rough physical geography, governmental mismanagement and misallocation of resources, and armed conflict.

# %% [markdown]
# ### 3. (5 pts.) What does the following line of code do when added to ggplot? scale_x_continuous(trans = 'log', breaks = 1000* 2**(0:10))

# %% [markdown]
# The line of code above when added to the ggplot adjusts the scale of the X-axis by creating breaks that begin at 1000 and increase as such: n=1000, n2=(n^2),...n3(n2^2). This makes the graph more visually appealing.

# %% [markdown]
# ### 4. (5 pts.) Google the “labs” command and use it to add informative x and y labels to your previous graph. Also use the “caption” argument in the labs command to add “Source: Gapminder” to the lower right corner of the graph.

# %%
ggplot(data = gapminder07) + 
    geom_text(mapping = aes(x = gdpPercap, y = lifeExp, label = country)) +
    coord_trans(x="log") +
    labs(caption = "Source: GapMinder") +
    xlab("Natural Log of GDP per Capita") +
    ylab("Life Expectancy") +
    geom_smooth(mapping = aes(x = gdpPercap, y = lifeExp), method = "lm", se = FALSE) +
    scale_x_continuous(trans = 'log', breaks = 1000* 2**(0:10))
# Out:
# plot without title

# %% [markdown]
# ## Section 3 Exercises

# %% [markdown]
# ### 1. (5 pts.) What happens if you facet on a continuous variable and why?

# %% [markdown]
# If you facet on a continous variable you will get one row or column for each unique value of the variable. This process can be very slow for variables that take a lot of values.

# %% [markdown]
# ### 2. (5 pts.) Try running the code below. What does . do?

# %% [markdown]
# Type Answer here.

# %% [markdown]
# ### 3. (5 pts.) Read ?facet_wrap. What does nrow do? What does ncol do? What other options control the layout of the individual panels? Why doesn’t facet_grid() have nrow and ncol arguments?

# %% [markdown]
# In `facet_wrap`, `nrow` and `ncol` control the numbers of rows and columns, but in `facet_grid` these are implied by the faceting variables. `dir` also controls the placement of the individual panels, and so isn't an argument of `facet_grid`.

# %% [markdown]
# ## Section 4 Exercises

# %% [markdown]
# ### 1. What geom would you use to draw a line chart? A boxplot? A histogram? An area chart?

# %% [markdown]
# For a line chart: `ggplot() + geom_line()` , for boxplot: `ggplot() + geom_boxplot()` , for a histogram: `ggplot() + geom_histogram()` , and for an area chart: `ggplot() + geom_area()`

# %% [markdown]
# ### 2. What does show.legend = FALSE do? What happens if you remove it?

# %% [markdown]
# The `show.legend = FALSE` argument removes the legend. It gives a cleaner visual plot when its clear that the grouping is done on a specific variable.

# %% [markdown]
# ### 3. (5 pts.) What does the se argument to geom_smooth() do?

# %% [markdown]
# The `se` argument when applied to `geom_smooth()` will specify whether to add a translucent background showing the confidence interval on the plot.

# %% [markdown]
# ### 4. (5 pts.) Will these two graphs look different? Why/why not?

# %% [markdown]
# The two graphs will look exactly the same (identical). This is because both graphs contain the same arguments but one graph attaches the arguments to the `ggplot()` so they don't have to be repeated for the `geom_point()` and `geom_smooth()` pieces of code. The other graph attaches the same arguments to `geom_point()` and `geom_smooth()` seperately.

# %% [markdown]
# ### 5. (15 pts.) Recreate the R code necessary to generate the following graphs (Edit: they are two separate graphs, not facets).

# %%
# Type Code in this cell that answers the question

# %% [markdown]
# ## Section 5 Exercises

# %% [markdown]
# ### 1. (5 pts.) What does geom_col() do? How is it different to geom_bar()? Google!

# %% [markdown]
# `geom_col` leaves the data as it is. `geom_bar()` creates two variables (count and prop) and then graphs the count data on the y axis. With `geom_col` you can plot the values.

# %% [markdown]
# ### 2. (5 pts.) In our proportion bar chart, we need to set group = 1. Why? In other words what is the problem with this graph?

# %% [markdown]
# `prop` finds proportions of the groups in the data. If we don't specify that we want all the data to be regarded as one group, then `geom_barchart` we end up with each category of data as a separate group and the proportion will be 1 for each.
